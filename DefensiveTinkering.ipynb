# %%
import numpy as np
import pandas as pd
from dill import dump, load
from nba_api.stats.static import players
from nba_api.stats.endpoints import leaguegamelog
from nba_api.stats.endpoints import leaguedashplayerstats
from nba_api.stats.endpoints import teamvsplayer

# %%
player_id = '1626157'
team_id = '1610612754'

x = teamvsplayer.TeamVsPlayer(player_id, team_id).get_data_frames()

# %%
x[-1]
# Out:
#     GROUP_SET     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME  VS_PLAYER_ID  \
# 0  Vs. Player  1610612754               IND  Indiana Pacers       1626157
# 1  Vs. Player  1610612754               IND  Indiana Pacers       1626157
# 2  Vs. Player  1610612754               IND  Indiana Pacers       1626157
# 3  Vs. Player  1610612754               IND  Indiana Pacers       1626157
# 4  Vs. Player  1610612754               IND  Indiana Pacers       1626157
# 5  Vs. Player  1610612754               IND  Indiana Pacers       1626157
# 6  Vs. Player  1610612754               IND  Indiana Pacers       1626157
#
#         VS_PLAYER_NAME COURT_STATUS            GROUP_VALUE  FGM  FGA  FG_PCT  \
# 0  Towns, Karl-Anthony          Off        Restricted Area   19   28   0.679
# 1  Towns, Karl-Anthony          Off  In The Paint (Non-RA)    2   13   0.154
# 2  Towns, Karl-Anthony          Off              Mid-Range    7   13   0.538
# 3  Towns, Karl-Anthony          Off          Left Corner 3    0    4   0.000
# 4  Towns, Karl-Anthony          Off         Right Corner 3    0    5   0.000
# 5  Towns, Karl-Anthony          Off      Above the Break 3    6   19   0.316
# 6  Towns, Karl-Anthony          Off              Backcourt    0    0   0.000
#
#    CFID CFPARAMS
# 0   216  1626157
# 1   217  1626157
# 2   218  1626157
# 3   219  1626157
# 4   220  1626157
# 5   221  1626157
# 6   222  1626157
